# %%
import numpy as np
from plots import plot_confusion_matrix
from load_data import load_db
from torchvision import transforms

# %%
a = np.array([0,1,0,1,0,1, 1, 1])
b = np.array([0,1,0,1,0,1, 0, 0])
plot_confusion_matrix(a, b, ['one', 'two'])

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

tr, va, te = load_db("CIFAR10",transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
tr.dataset.class_to_idx.keys()
# Out:
# dict_keys(['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
